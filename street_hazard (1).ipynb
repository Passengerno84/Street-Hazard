# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/SUMMER INTERN'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.5/609.5 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CEWLcHAnSp2uqt59TcvX")
project = rf.workspace("street-hazard-wquul").project("road-hazards")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 6.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.9 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=146dfcf299ec703a2f27d946160d884a64e15c3280ea88f3b12219f8c5d999f0
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=1000)  # train the model
# Out:
# Streaming output truncated to the last 5000 lines.
#      4/1000      2.63G      3.916      2.331      3.593        278        640: 100%|██████████| 11/11 [00:05<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:04<00:00,  1.45it/s]
#                    all        168       3008    0.00053    0.00681   0.000279   0.000115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      5/1000       2.6G      3.597      2.152      3.309        289        640: 100%|██████████| 11/11 [00:06<00:00,  1.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:04<00:00,  1.39it/s]
#                    all        168       3008   0.000971    0.00309    0.00049   0.000144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...

# %%
a = 10
print(a)
# Out:
# 10

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install aspose-words
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 MB 13.9 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source = '/content/gdrive/MyDrive/SUMMER INTERN/test_images2'
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006233 parameters, 0 gradients
#
# image 1/32 /content/gdrive/MyDrive/SUMMER INTERN/test_images2/1469.png: 384x640 2 cars, 4 traffic lights, 17 trees, 50.3ms
# image 2/32 /content/gdrive/MyDrive/SUMMER INTERN/test_images2/1470.png: 384x640 1 car, 17 trees, 5.8ms
# image 3/32 /content/gdrive/MyDrive/SUMMER INTERN/test_images2/1471.png: 384x640 1 car, 14 trees, 5.8ms
# image 4/32 /content/gdrive/MyDrive/SUMMER INTERN/test_images2/1472.png: 384x640 3 cars, 17 trees, 6.1ms
# image 5/32 /content/gdrive/MyDrive/SUMMER INTERN/test_images2/1473.png: 384x640 18 trees, 7.2ms
# image 6/32 /content/gdrive/MyDrive/SUMMER INTERN/test_images2/1474.png: 384x640 19 trees, 5.9ms
# image 7/32 /content/gdrive/MyDrive/SUMMER INTERN/test_images2/1475.png: 384x640 21 trees, 7.1ms
# image 8/32 /content/gdrive/MyDrive/SUMMER INTERN/test_images2/1476.png: 384x640 14 trees, 7.8ms
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/SUMMER INTERN'

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/SUMMER INTERN'
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-5-683568506ba0> in <cell line: 1>()
# ----> 1 get_ipython().system("scp -r /content/runs '/content/gdrive/My Drive/SUMMER INTERN'")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     451   # is expected to call this function, thus adding one level of nesting to the
#     452   # stack.
# --> 453   result = _run_command(
#     454       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     455   )
#
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source = '/content/gdrive/MyDrive/SUMMER INTERN/test_images'
